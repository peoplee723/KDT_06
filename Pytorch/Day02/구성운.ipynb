# %%
import torch                    #텐서 및 수치 계산 모듈
import torch.nn as nn           #인공신경망
import torch.nn.functional as F      #손실, 거리 계산 모듈
import torch.optim as optimizer # 최적화 기법 모듈
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from func import Torch_preccesing

# %%
# 데이터 불러오기
FILE='../data/boston.csv'
bostonDF=pd.read_csv(FILE)
bostonDF.head()
bostonTS=Torch_preccesing(bostonDF)

# %%
# 모델 준비
torch.manual_seed(1)

bostonTS.model=nn.Linear(13,1)

bostonTS.look_params()####?????
# Out:
# weight Parameter containing:
# tensor([[ 0.1429, -0.1224, -0.0538,  0.1302, -0.2611,  0.1663, -0.0571,  0.1411,
#           0.0386, -0.0340,  0.0769,  0.0137,  0.1013]], requires_grad=True)
#
# bias Parameter containing:
# tensor([-0.1081], requires_grad=True)

# %%
# 최적화 인스턴스 생성  #생성 함수 만들 필요가 있을까?
bostonTS.optim=optimizer.Adam(bostonTS.model.parameters(), lr=0.1)

# %%
bostonTS.data.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
# tesor화 테스트
bostonTS.make_tensor(feature=['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
       'PTRATIO', 'B', 'LSTAT'], target='MEDV')
# Out:
# torch.Size([506, 13]) torch.Size([506, 1])

# %%
# 분리

bostonTS.split()
# Out:
# X_train: torch.Size([284, 13]),2
# X_test: torch.Size([127, 13]),2
# Y_train: torch.Size([284, 1]),2
# Y_test: torch.Size([127, 1]),2

# %%
# 학습 진행
bostonTS.training(epoch=100)
# Out:
# [kind] LOSS: 3546.50244140625
# [1/100] LOSS: 1136.7435302734375
# [kind] LOSS: 815.6141357421875
# [2/100] LOSS: 3846.5615234375
# [kind] LOSS: 441.84814453125
# [3/100] LOSS: 927.4158325195312
# [kind] LOSS: 1913.180908203125
# [4/100] LOSS: 395.9892272949219
# [kind] LOSS: 1439.9232177734375
# [5/100] LOSS: 1832.2137451171875
# [kind] LOSS: 283.229736328125
# [6/100] LOSS: 1354.6180419921875
# [kind] LOSS: 224.33309936523438
# [7/100] LOSS: 236.1881103515625
# [kind] LOSS: 849.6485595703125
# [8/100] LOSS: 274.4693603515625
# [kind] LOSS: 853.9561767578125
# [9/100] LOSS: 988.2904052734375
# [kind] LOSS: 312.82568359375
# [10/100] LOSS: 995.2891845703125
# [kind] LOSS: 100.8172836303711
# [11/100] LOSS: 382.289794921875
# [kind] LOSS: 465.7002868652344
# [12/100] LOSS: 84.2166519165039
# [kind] LOSS: 784.4337158203125
# [13/100] LOSS: 393.55596923828125
# [kind] LOSS: 598.5123291015625
# [14/100] LOSS: 694.239501953125
# [kind] LOSS: 206.69522094726562
# ...

# %%
bostonTS.diff_check()
