# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.linear_model import ElasticNet, Ridge, Lasso, LinearRegression
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
from sklearn.datasets import load_iris
from func import linear_model
# 데이터 로딩
DATA='./Data/iris.csv'
iris=pd.read_csv(DATA)
print(iris.head())
print(iris.columns)
iris['num']=iris['variety'].replace({'Setosa': 0, 'Versicolor':1, "Virginica":2})
print(iris.head())
iris_DF= linear_model(iris)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')
#    sepal.length  sepal.width  petal.length  petal.width variety  num
# 0           5.1          3.5           1.4          0.2  Setosa    0
# 1           4.9          3.0           1.4          0.2  Setosa    0
# 2           4.7          3.2           1.3          0.2  Setosa    0
# 3           4.6          3.1           1.5          0.2  Setosa    0
# 4           5.0          3.6           1.4          0.2  Setosa    0

# %%
iris_DF.split(featureN=iris[['sepal.length', 'sepal.width', 'petal.length', 'petal.width']], target=iris['num'], testsize=.3,
              stratify=iris['num'] )

iris_DF.get_scaled('MinMaxScaler')
# 스케일링
# irisDF.get_scaled('MinMaxScaler')

iris_DF.get_best_model('Ridge', {'alpha': [1,2,3,4]}, cv=5, scoring='r2')
# Out:
# X_train: (105, 4),2
# X_test: (45, 4),2
# Y_train: (105,),1
# Y_test: (45,),1
# X_train_scaled: (105, 4),2
# X_test_scaled: (45, 4),2
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 0       0.005196      0.006289         0.000434        0.000466           1
# 1       0.000598      0.000488         0.000399        0.000488           2
# 2       0.000460      0.000452         0.000199        0.000399           3
# 3       0.000000      0.000000         0.000000        0.000000           4
#
#          params  split0_test_score  split1_test_score  split2_test_score  \
# 0  {'alpha': 1}           0.895518           0.876145           0.907237
# 1  {'alpha': 2}           0.882599           0.861975           0.895228
# 2  {'alpha': 3}           0.869546           0.850155           0.882763
# 3  {'alpha': 4}           0.855781           0.838322           0.869529
#
#    split3_test_score  ...  mean_test_score  std_test_score  rank_test_score  \
# ...

# %%
iris_DF.best_model.score(iris_DF.X_test_scaled, iris_DF.Y_test)
# Out:
# 0.9480794083805308

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 4
#       2 b=[4,5,6,7,8]
#       3 c=[7,8,9,10,11]
# ----> 4 for i, j, k in [a,b,c]:
#       5     print(i,j,k)
#
# ValueError: too many values to unpack (expected 3)
