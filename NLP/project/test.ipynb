# %%
import pandas as pd

# %%
# Out:
# 0.9090909090909091

# %%
a= pd.date_range(start='1/1/2024', end='10/10/2024', freq='D')
time_stamp=[]
for i in a:
    if i.month//10<=0 and i.day//10<=0:
        a=str(0)+str(i.month); b='0'+str(i.day)
    elif i.day//10<=0 and i.day//10>=0:
        b='0'+str(i.day); b=str(i.day)
    elif i.day//10>=0 and i.day//10<=0:
        a=str(i.month); b='0'+str(i.day)
    elif i.day//10>=0 and i.day//10>=0:
        a=str(i.month); b=str(i.day)
    time_stamp.append('2024'+a+b)
print(time_stamp)
# Out:
# ['20240101', '20240102', '20240103', '20240104', '20240105', '20240106', '20240107', '20240108', '20240109', '2024110', '2024111', '2024112', '2024113', '2024114', '2024115', '2024116', '2024117', '2024118', '2024119', '2024120', '2024121', '2024122', '2024123', '2024124', '2024125', '2024126', '2024127', '2024128', '2024129', '2024130', '2024131', '20240201', '20240202', '20240203', '20240204', '20240205', '20240206', '20240207', '20240208', '20240209', '2024210', '2024211', '2024212', '2024213', '2024214', '2024215', '2024216', '2024217', '2024218', '2024219', '2024220', '2024221', '2024222', '2024223', '2024224', '2024225', '2024226', '2024227', '2024228', '2024229', '20240301', '20240302', '20240303', '20240304', '20240305', '20240306', '20240307', '20240308', '20240309', '2024310', '2024311', '2024312', '2024313', '2024314', '2024315', '2024316', '2024317', '2024318', '2024319', '2024320', '2024321', '2024322', '2024323', '2024324', '2024325', '2024326', '2024327', '2024328', '2
# ...

# %%
time_list=[]
for a in range(273):
    time_list.append(pd.Timestamp(19723+a, unit="D").strftime("%Y%m%d"))

print(len(time_list))
# Out:
# 273

# %%
19996-19723
# Out:
# 273
